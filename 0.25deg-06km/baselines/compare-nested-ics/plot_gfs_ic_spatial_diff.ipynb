# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr

# %%
plt.style.use("~/nice.mplstyle")

# %% [markdown]
# ## Compare Nested-EAGLE with GFS ICs vs Global-EAGLE
#
# Differences highlight the model constraints, rather than IC differences
#
# It's interesting to see the global picture, there are some differences outside of CONUS at the first time step.
# However, these clearly don't materialize into better skill.

# %%
ds = xr.open_dataset("/pscratch/sd/t/timothys/nested-eagle/0.25deg-06km/production/gfs-hrrr/stage1c/inference-testing/spatial-metrics-gfsguys/spatial.rmse.nested-globalvglobal.fc1vfc2.nc")
ds = ds.sel(
    latitude=slice(55, 20),
    longitude=slice(215, 315),
    fhr=slice(1,49),
)

# %%
ads = ds - ds.mean("fhr")

# %%
ds.t2m.plot(col="fhr", col_wrap=4, vmax=None, vmin=0)
#ads.t2m.plot(col="fhr", col_wrap=4)
# Out:
# /global/homes/t/timothys/.conda/envs/eagle/lib/python3.12/site-packages/xarray/plot/facetgrid.py:685: UserWarning: The figure layout has changed to tight
#   self.fig.tight_layout()

# %%
ds["10m_wind_speed"].plot(col="fhr", col_wrap=4, vmax=None, vmin=0)
#ads["10m_wind_speed"].plot(col="fhr", col_wrap=4)
# Out:
# /global/homes/t/timothys/.conda/envs/eagle/lib/python3.12/site-packages/xarray/plot/facetgrid.py:685: UserWarning: The figure layout has changed to tight
#   self.fig.tight_layout()

# %%
ds["sh2"].isel(fhr=slice(8)).plot(col="fhr", col_wrap=4, vmax=None, vmin=0)
#ads["sh2"].plot(col="fhr", col_wrap=4)
# Out:
# /global/homes/t/timothys/.conda/envs/eagle/lib/python3.12/site-packages/xarray/plot/facetgrid.py:685: UserWarning: The figure layout has changed to tight
#   self.fig.tight_layout()

# %%
ds["sp"].plot(col="fhr", col_wrap=4, vmax=None, vmin=0)
#ads["sp"].plot(col="fhr", col_wrap=4)
# Out:
# /global/homes/t/timothys/.conda/envs/eagle/lib/python3.12/site-packages/xarray/plot/facetgrid.py:685: UserWarning: The figure layout has changed to tight
#   self.fig.tight_layout()

# %%
ds.gh.sel(level=850).plot(col="fhr", col_wrap=4, vmax=None, vmin=0)
# Out:
# /global/homes/t/timothys/.conda/envs/eagle/lib/python3.12/site-packages/xarray/plot/facetgrid.py:685: UserWarning: The figure layout has changed to tight
#   self.fig.tight_layout()

# %%
ds.t.sel(level=250).plot(col="fhr", col_wrap=4, vmax=None, vmin=0)

# %%
ds.q.sel(level=850).plot(col="fhr", col_wrap=4, vmax=None, vmin=0)
# Out:
# /global/homes/t/timothys/.conda/envs/eagle/lib/python3.12/site-packages/xarray/plot/facetgrid.py:685: UserWarning: The figure layout has changed to tight
#   self.fig.tight_layout()

# %%
ds.v.sel(level=500).plot(col="fhr", col_wrap=4, vmax=None, vmin=0)
# Out:
# /global/homes/t/timothys/.conda/envs/eagle/lib/python3.12/site-packages/xarray/plot/facetgrid.py:685: UserWarning: The figure layout has changed to tight
#   self.fig.tight_layout()
