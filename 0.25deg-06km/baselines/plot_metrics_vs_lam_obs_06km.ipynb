# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import seaborn as sns

# %%
from niceplots import plot_surface_vars, plot_level_vars

# %%
plt.style.use("~/nice.mplstyle")

# %%
metric = "rmse"
rmse = {}
valortest = "testing"
#rmse["Nested-EAGLE Experimental"] = xr.load_dataset(f"/pscratch/sd/t/timothys/nested-eagle/0.25deg-06km/mse24h/experiments/data-years/all/inference-{valortest}/obs-metrics/{metric}.convobs.nested-lam.nc", decode_timedelta=True)
rmse["Nested-EAGLE 0.25\u00B0/06km"] = xr.load_dataset(f"/pscratch/sd/t/timothys/nested-eagle/0.25deg-06km/production/gfs-hrrr/stage1c/inference-{valortest}/obs-metrics/{metric}.convobs.nested-lam.nc", decode_timedelta=True)
rmse["HRRR"] = xr.load_dataset(f"/pscratch/sd/t/timothys/nested-eagle/0.25deg-06km/baselines/hrrr-forecasts-vs-hrrr-analysis/trim25/obs-metrics-{valortest}/{metric}.convobs.lam.nc", decode_timedelta=True)
rmse["GFS"] = xr.load_dataset(f"/pscratch/sd/t/timothys/nested-eagle/0.25deg-06km/baselines/gfs-forecasts-vs-hrrr-analysis/trim25/obs-metrics-{valortest}/{metric}.convobs.lam.nc", decode_timedelta=True)

# %%
metric = "mae"
mae = {}
valortest = "testing"
#mae["Nested-EAGLE Experimental"] = xr.load_dataset(f"/pscratch/sd/t/timothys/nested-eagle/0.25deg-06km/mse24h/experiments/data-years/all/inference-{valortest}/obs-metrics/{metric}.convobs.nested-lam.nc", decode_timedelta=True)
mae["Nested-EAGLE 0.25\u00B0/06km"] = xr.load_dataset(f"/pscratch/sd/t/timothys/nested-eagle/0.25deg-06km/production/gfs-hrrr/stage1c/inference-{valortest}/obs-metrics/{metric}.convobs.nested-lam.nc", decode_timedelta=True)
mae["HRRR"] = xr.load_dataset(f"/pscratch/sd/t/timothys/nested-eagle/0.25deg-06km/baselines/hrrr-forecasts-vs-hrrr-analysis/trim25/obs-metrics-{valortest}/{metric}.convobs.lam.nc", decode_timedelta=True)
mae["GFS"] = xr.load_dataset(f"/pscratch/sd/t/timothys/nested-eagle/0.25deg-06km/baselines/gfs-forecasts-vs-hrrr-analysis/trim25/obs-metrics-{valortest}/{metric}.convobs.lam.nc", decode_timedelta=True)

# %%
fig, axs = plot_surface_vars(rmse, metric_name="RMSE", sel={"fhr": slice(49)}, marker="o")
#fig.savefig(f"figures/surface_48h_rmse_5fields.jpeg", dpi=300, bbox_inches="tight")
# Out:
# /global/u2/t/timothys/nested-eagle/0.25deg-06km/baselines/niceplots.py:51: UserWarning: The figure layout has changed to tight
#   plt.tight_layout(pad=0, rect=[0, 0.1, 1, 1])

# %%
fig, axs = plot_surface_vars(rmse, metric_name="RMSE")
#fig.savefig(f"figures/surface_10d_rmse_5fields.jpeg", dpi=300, bbox_inches="tight")
# Out:
# /global/u2/t/timothys/nested-eagle/0.25deg-06km/baselines/niceplots.py:51: UserWarning: The figure layout has changed to tight
#   plt.tight_layout(pad=0, rect=[0, 0.1, 1, 1])

# %%
fig, axs = plot_surface_vars(mae, metric_name="MAE")
# Out:
# /global/u2/t/timothys/nested-eagle/0.25deg-06km/baselines/niceplots.py:51: UserWarning: The figure layout has changed to tight
#   plt.tight_layout(pad=0, rect=[0, 0.1, 1, 1])

# %%
fig, axs = plot_level_vars(rmse, metric_name="RMSE", sel={"fhr": slice(49)}, marker="o")
#fig.savefig(f"figures/plevel_48h_rmse_6fields.jpeg", dpi=300, bbox_inches="tight")

# %%
fig, axs = plot_level_vars(rmse, metric_name="RMSE")
#fig.savefig(f"figures/plevel_10d_rmse_6fields.jpeg", dpi=300, bbox_inches="tight")

# %%
fig, axs = plot_level_vars(mae, metric_name="MAE")
