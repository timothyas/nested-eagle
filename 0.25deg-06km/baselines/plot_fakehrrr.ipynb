# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import seaborn as sns

import string

# %%
from niceplots import plot_surface_vars, plot_level_vars

# %%
plt.style.use("~/nice.mplstyle")

# %%
metric = "rmse"
subregion = ".conus" # Note, blank string gives global evaluation

valortest = "testing"

rmse = {}
#rmse["Nested-EAGLE Experimental"] = xr.load_dataset(f"/pscratch/sd/t/timothys/nested-eagle/0.25deg-06km/mse24h/experiments/data-years/all/inference-validation/obs-metrics/{metric}.convobs.nested-global{subregion}.nc", decode_timedelta=True)
rmse["Nested-EAGLE"] = xr.load_dataset(f"/pscratch/sd/t/timothys/nested-eagle/0.25deg-06km/production/gfs-hrrr/stage1c/inference-{valortest}/obs-metrics/{metric}.convobs.nested-global{subregion}.nc", decode_timedelta=True)
rmse["Global-EAGLE"] = xr.load_dataset(f"/pscratch/sd/t/timothys/nested-eagle/0.25deg-06km/production/gfs-only/stage1c/inference-{valortest}/obs-metrics/{metric}.convobs.global{subregion}.nc", decode_timedelta=True)
rmse["Nested-EAGLE - GFS Init"] = xr.load_dataset(f"/pscratch/sd/t/timothys/nested-eagle/0.25deg-06km/production/gfs-hrrr/stage1c/inference-{valortest}-fakehrrr/obs-metrics/{metric}.convobs.nested-global{subregion}.nc", decode_timedelta=True)
rmse["Global-EAGLE - HRRR Init"] = xr.load_dataset(f"/pscratch/sd/t/timothys/nested-eagle/0.25deg-06km/production/gfs-only/stage1c/inference-{valortest}-fakegfs/obs-metrics/{metric}.convobs.global{subregion}.nc", decode_timedelta=True)

# These were to look at surface pressure, which is really dependent on the resolution of the evaluation itself, as well as the ICs
#rmse["FakeHRRR 6km"] = xr.load_dataset(f"/pscratch/sd/t/timothys/nested-eagle/0.25deg-06km/production/gfs-hrrr/stage1c/inference-{valortest}-fakehrrr/obs-metrics/{metric}.convobs.nested-lam.nc", decode_timedelta=True)
#rmse["Nested Native"] = xr.load_dataset(f"/pscratch/sd/t/timothys/nested-eagle/0.25deg-06km/production/gfs-hrrr/stage1c/inference-{valortest}/obs-metrics/{metric}.convobs.nested-lam.nc", decode_timedelta=True)
rmse["GFS"] = xr.load_dataset(f"/pscratch/sd/t/timothys/nested-eagle/0.25deg-06km/baselines/gfs-forecasts-vs-gfs-analysis/obs-metrics-{valortest}/{metric}.convobs.global{subregion}.nc", decode_timedelta=True)

# %%
metric = "mae"
subregion = ".conus" # Note, blank string gives global evaluation

valortest = "testing"

mae = {}
#mae["Nested-EAGLE Experimental"] = xr.load_dataset(f"/pscratch/sd/t/timothys/nested-eagle/0.25deg-06km/mse24h/experiments/data-years/all/inference-validation/obs-metrics/{metric}.convobs.nested-global{subregion}.nc", decode_timedelta=True)
mae["Nested-EAGLE"] = xr.load_dataset(f"/pscratch/sd/t/timothys/nested-eagle/0.25deg-06km/production/gfs-hrrr/stage1c/inference-{valortest}/obs-metrics/{metric}.convobs.nested-global{subregion}.nc", decode_timedelta=True)
mae["Global-EAGLE"] = xr.load_dataset(f"/pscratch/sd/t/timothys/nested-eagle/0.25deg-06km/production/gfs-only/stage1c/inference-{valortest}/obs-metrics/{metric}.convobs.global{subregion}.nc", decode_timedelta=True)
mae["Nested-EAGLE - GFS Init"] = xr.load_dataset(f"/pscratch/sd/t/timothys/nested-eagle/0.25deg-06km/production/gfs-hrrr/stage1c/inference-{valortest}-fakehrrr/obs-metrics/{metric}.convobs.nested-global{subregion}.nc", decode_timedelta=True)
mae["Global-EAGLE - HRRR Init"] = xr.load_dataset(f"/pscratch/sd/t/timothys/nested-eagle/0.25deg-06km/production/gfs-only/stage1c/inference-{valortest}-fakegfs/obs-metrics/{metric}.convobs.global{subregion}.nc", decode_timedelta=True)
# These were to look at surface pressure, which is really dependent on the resolution of the evaluation itself, as well as the ICs
#mae["FakeHRRR 6km"] = xr.load_dataset(f"/pscratch/sd/t/timothys/nested-eagle/0.25deg-06km/production/gfs-hrrr/stage1c/inference-{valortest}-fakehrrr/obs-metrics/{metric}.convobs.nested-lam.nc", decode_timedelta=True)
#mae["Nested Native"] = xr.load_dataset(f"/pscratch/sd/t/timothys/nested-eagle/0.25deg-06km/production/gfs-hrrr/stage1c/inference-{valortest}/obs-metrics/{metric}.convobs.nested-lam.nc", decode_timedelta=True)
mae["GFS"] = xr.load_dataset(f"/pscratch/sd/t/timothys/nested-eagle/0.25deg-06km/baselines/gfs-forecasts-vs-gfs-analysis/obs-metrics-{valortest}/{metric}.convobs.global{subregion}.nc", decode_timedelta=True)

# %%
fig, axs = plot_surface_vars(rmse, metric_name="RMSE", estimator="mean")
# Out:
# /global/u2/t/timothys/nested-eagle/0.25deg-06km/baselines/niceplots.py:59: UserWarning: The figure layout has changed to tight
#   plt.tight_layout(pad=0, rect=[0, 0.1, 1, 1])

# %%
fig, axs = plot_surface_vars(rmse, metric_name="RMSE")
# Out:
# /global/u2/t/timothys/nested-eagle/0.25deg-06km/baselines/niceplots.py:59: UserWarning: The figure layout has changed to tight
#   plt.tight_layout(pad=0, rect=[0, 0.1, 1, 1])

# %%
fig, axs = plot_surface_vars(mae, metric_name="MAE")
# Out:
# /global/u2/t/timothys/nested-eagle/0.25deg-06km/baselines/niceplots.py:59: UserWarning: The figure layout has changed to tight
#   plt.tight_layout(pad=0, rect=[0, 0.1, 1, 1])

# %%
fig, axs = plot_level_vars(rmse, metric_name="RMSE")

# %%
fig, axs = plot_level_vars(mae, metric_name="MAE")
